# %% [markdown]
# # Identify duplicate rows (except for density) in source data
#
# 10/30, 5/8,7/2023

# %%
from pathlib import Path

import pandas as pd

# %%
data_pth = Path(".")

# %% [markdown]
# ## Look for duplicate density emof records in the emof table

# %%
emof_df = pd.read_csv(data_pth / 'aligned_csvs' / 'DwC_emof.csv')

# %%
emof_density_df = emof_df[emof_df['measurementTypeID'] == "http://vocab.nerc.ac.uk/collection/P01/current/SDBIOL01/"]

# %% [markdown]
# There they are, duplicates!

# %%
emof_density_valuecounts_df = pd.DataFrame(
    emof_density_df.occurrenceID.value_counts()
).rename(columns={'occurrenceID':'count'})

emof_density_valuecounts_df.head()
# Out:
#                                       count
# f6ef5d18-03ac-4d21-979e-ed69470f29ef      2
# 4b8fff24-04e2-418c-b1be-44d471b25610      2
# 6feab017-be10-415b-865a-70cdccaf9bc6      2
# 5bf63e21-448a-4672-974c-47c60b67d4fc      2
# 938734f0-be6c-4aee-aad9-767a11d66eca      2

# %% [markdown]
# **There it is, the 30 duplicates!**

# %%
len(emof_density_valuecounts_df.query("count > 1"))
# Out:
# 30

# %% [markdown]
# An example:

# %%
emof_density_df[emof_density_df['occurrenceID'] == '73aa9fe2-b55b-4aaa-8ac5-d7f3eaff21ac']
# Out:
# Empty DataFrame
# Columns: [eventID, occurrenceID, measurementType, measurementTypeID, measurementValue, measurementValueID, measurementUnit, measurementUnitID]
# Index: []

# %% [markdown]
# The problem is that there are records in the source table that are practically duplicates, in everything **except the `density` values!**

# %% [markdown]
# ## Look for such duplicates by loading the source csv, dropping `density` (and `time`), and identifying duplicates in the dataframe.

# %%
sourcecsvdata_pth = data_pth / "sourcedata" / "bcodmo_dataset_682074_data.csv"

source_df = pd.read_csv(sourcecsvdata_pth, skiprows=[1])

source_dropcols_df = source_df.drop(columns=['density', 'time'])

# %%
len(source_dropcols_df[source_dropcols_df.duplicated()])
# Out:
# 17

# %%
source_dropcols_df[source_dropcols_df.duplicated()]
# Out:
#      station  latitude  longitude day_night               species      date  \
# 982       DB    47.378   -123.117       Day  OITHONA_SPINIROSTRIS  20131003
# 1008      DB    47.378   -123.117       Day             OSTRACODA  20120712
# 1289      DB    47.378   -123.117       Day         PSEUDOCALANUS  20131003
# 1847      DB    47.378   -123.117     Night    EUPHAUSIA_PACIFICA  20120905
# 1852      DB    47.378   -123.117     Night    EUPHAUSIA_PACIFICA  20120905
# 3599      HP    47.581   -122.986     Night         PSEUDOCALANUS  20131001
# 3807      UN    47.812   -122.807       Day              BIVALVIA  20130930
# 4397      UN    47.812   -122.807       Day            GASTROPODA  20120902
# 4438      UN    47.812   -122.807       Day             GRAPSIDAE  20120709
# 4440      UN    47.812   -122.807       Day             GRAPSIDAE  20120709
# 4937      UN    47.812   -122.807       Day             PAGURIDAE  20120709
# 5005      UN    47.812   -122.807       Day    PARACALANUS_PARVUS  20121001
# 5007      UN    47.812   -122.807       Day    PARACALANUS_PARVUS  20121001
# 5062      UN    47.812   -122.807       Day    PARACALANUS_PARVUS  20130903
# 5313      UN    47.812   -122.807       Day         PSEUDOCALANUS  20130930
# 5360      UN    47.812   -122.807       Day   THYSANOESSA_RASCHII  20120709
# 6449      UN    47.812   -122.807     Night                ONCAEA  20120709
#
#      time_start life_history_stage         sample_code  mesh_size  depth_max  \
# 982       14:11         Copepodite   20131003DBDm2_200        200       56.0
# 1008      16:23            Unknown   20120712DBDm1_200        200       70.0
# 1289      14:11      Female;_Adult   20131003DBDm4_200        200       16.0
# 1847      23:19     F3;_Furcilia_3  20120905DBBNm4_335        335       20.0
# 1852      23:19     F3;_Furcilia_3  20120905DBBNm5_335        335        9.0
# 3599      20:57         Copepodite   20131001HPNm1_200        200      103.0
# 3807      13:54            Unknown   20130930UNDm5_200        200        6.0
# 4397      15:13            Unknown   20120902UNDm5_200        200        7.0
# 4438      17:30       Z3;_Zoea_III   20120709UNDm4_335        335        8.0
# 4440      17:30        Z4;_Zoea_IV   20120709UNDm4_335        335        8.0
# 4937      17:30         Z1;_Zoea_I   20120709UNDm4_335        335        8.0
# 5005      14:12      Female;_Adult   20121001UNDm2_200        200       57.0
# 5007      14:12        Male;_Adult   20121001UNDm2_200        200       57.0
# 5062      14:38             4;_CIV   20130903UNDm2_200        200       40.0
# 5313      13:54         Copepodite   20130930UNDm1_200        200       59.0
# 5360      17:30     F1;_Furcilia_1   20120709UNDm4_335        335        8.0
# 6449      22:10         Copepodite   20120709UNNm4_200        200        8.0
#
#       depth_min FWC_DS
# 982        30.0     DS
# 1008       45.0     DS
# 1289       12.0     DS
# 1847        9.0     DS
# 1852        0.0     DS
# 3599        0.0    FWC
# 3807        0.0     DS
# 4397        0.0     DS
# 4438        0.0     DS
# 4440        0.0     DS
# 4937        0.0     DS
# 5005       40.0     DS
# 5007       40.0     DS
# 5062       20.0     DS
# 5313        0.0    FWC
# 5360        0.0     DS
# 6449        0.0     DS

# %% [markdown]
# Distill to the bare minimum information needed to describe (convey to others) these duplicates

# %%
cols = ['sample_code', 'species', 'life_history_stage']

source_duplicated_df = source_dropcols_df[source_dropcols_df.duplicated()][cols].sort_values(by=cols)

# %%
len(source_duplicated_df)
# Out:
# 17

# %% [markdown]
# **Hmm, that's only 17, NOT 30!** Could it be that some of the duplication problems actually made it into the occurrence table, and the generation of the `occurrenceID` values?

# %%
source_duplicated_df
# Out:
#              sample_code               species life_history_stage
# 4438   20120709UNDm4_335             GRAPSIDAE       Z3;_Zoea_III
# 4440   20120709UNDm4_335             GRAPSIDAE        Z4;_Zoea_IV
# 4937   20120709UNDm4_335             PAGURIDAE         Z1;_Zoea_I
# 5360   20120709UNDm4_335   THYSANOESSA_RASCHII     F1;_Furcilia_1
# 6449   20120709UNNm4_200                ONCAEA         Copepodite
# 1008   20120712DBDm1_200             OSTRACODA            Unknown
# 4397   20120902UNDm5_200            GASTROPODA            Unknown
# 1847  20120905DBBNm4_335    EUPHAUSIA_PACIFICA     F3;_Furcilia_3
# 1852  20120905DBBNm5_335    EUPHAUSIA_PACIFICA     F3;_Furcilia_3
# 5005   20121001UNDm2_200    PARACALANUS_PARVUS      Female;_Adult
# 5007   20121001UNDm2_200    PARACALANUS_PARVUS        Male;_Adult
# 5062   20130903UNDm2_200    PARACALANUS_PARVUS             4;_CIV
# 5313   20130930UNDm1_200         PSEUDOCALANUS         Copepodite
# 3807   20130930UNDm5_200              BIVALVIA            Unknown
# 3599   20131001HPNm1_200         PSEUDOCALANUS         Copepodite
# 982    20131003DBDm2_200  OITHONA_SPINIROSTRIS         Copepodite
# 1289   20131003DBDm4_200         PSEUDOCALANUS      Female;_Adult

# %% [markdown]
# ## Look for duplicate occurrence records in the occurrence table

# %%
occurrence_df = pd.read_csv(data_pth / 'aligned_csvs' / 'DwC_occurrence.csv')

len(occurrence_df)
# Out:
# 6871

# %%
occurrence_dropoccurrenceID_df = occurrence_df.drop(columns=['occurrenceID'])

# %%
occurrence_dropoccurrenceID_df.head()
# Out:
#              eventID   basisOfRecord occurrenceStatus            sex  \
# 0  20120611UNDm1_200  MaterialSample          present         female
# 1  20120611UNDm1_200  MaterialSample          present           male
# 2  20120611UNDm1_200  MaterialSample          present  indeterminate
# 3  20120611UNDm1_200  MaterialSample          present  indeterminate
# 4  20120611UNDm1_200  MaterialSample          present  indeterminate
#
#         lifeStage                                         dwciri:sex  \
# 0           adult  http://vocab.nerc.ac.uk/collection/S10/current...
# 1           adult  http://vocab.nerc.ac.uk/collection/S10/current...
# 2  copepodites C5  http://vocab.nerc.ac.uk/collection/S10/current...
# 3         medusae  http://vocab.nerc.ac.uk/collection/S10/current...
# 4         veliger  http://vocab.nerc.ac.uk/collection/S10/current...
#
#                                     dwciri:lifeStage  scientificName  \
# 0  http://vocab.nerc.ac.uk/collection/S11/current...  Acartia clausi
# 1  http://vocab.nerc.ac.uk/collection/S11/current...  Acartia clausi
# 2  http://vocab.nerc.ac.uk/collection/S11/current...  Acartia clausi
# 3  http://vocab.nerc.ac.uk/collection/S11/current...        Aglantha
# 4  http://vocab.nerc.ac.uk/collection/S11/current...        Bivalvia
#
#                             scientificNameID taxonRank   kingdom      phylum  \
# 0  urn:lsid:marinespecies.org:taxname:104251   Species  Animalia  Arthropoda
# 1  urn:lsid:marinespecies.org:taxname:104251   Species  Animalia  Arthropoda
# 2  urn:lsid:marinespecies.org:taxname:104251   Species  Animalia  Arthropoda
# 3  urn:lsid:marinespecies.org:taxname:117212     Genus  Animalia    Cnidaria
# 4     urn:lsid:marinespecies.org:taxname:105     Class  Animalia    Mollusca
#
#       class          order            family     genus  \
# 0  Copepoda      Calanoida        Acartiidae   Acartia
# 1  Copepoda      Calanoida        Acartiidae   Acartia
# 2  Copepoda      Calanoida        Acartiidae   Acartia
# 3  Hydrozoa  Trachymedusae  Rhopalonematidae  Aglantha
# 4  Bivalvia            NaN               NaN       NaN
#
#   scientificNameAuthorship verbatimIdentification
# 0         Giesbrecht, 1889         ACARTIA_CLAUSI
# 1         Giesbrecht, 1889         ACARTIA_CLAUSI
# 2         Giesbrecht, 1889         ACARTIA_CLAUSI
# 3            Haeckel, 1879               AGLANTHA
# 4           Linnaeus, 1758               BIVALVIA

# %%
cols = ['eventID', 'verbatimIdentification', 'scientificName', 'sex', 'lifeStage']

occurrence_duplicated_df = occurrence_dropoccurrenceID_df[occurrence_dropoccurrenceID_df.duplicated()][cols].sort_values(by=cols)

len(occurrence_duplicated_df)
# Out:
# 17

# %% [markdown]
# **The same 17 duplicates from the source file.** Makes sense.

# %%
occurrence_duplicated_df
# Out:
#                  eventID verbatimIdentification        scientificName  \
# 1196   20120709UNDm4_335              GRAPSIDAE             Grapsidae
# 1198   20120709UNDm4_335              GRAPSIDAE             Grapsidae
# 1200   20120709UNDm4_335              PAGURIDAE             Paguridae
# 1204   20120709UNDm4_335    THYSANOESSA_RASCHII   Thysanoessa raschii
# 1441   20120709UNNm4_200                 ONCAEA                Oncaea
# 1595   20120712DBDm1_200              OSTRACODA             Ostracoda
# 2364   20120902UNDm5_200             GASTROPODA            Gastropoda
# 2693  20120905DBBNm4_335     EUPHAUSIA_PACIFICA    Euphausia pacifica
# 2712  20120905DBBNm5_335     EUPHAUSIA_PACIFICA    Euphausia pacifica
# 3100   20121001UNDm2_200     PARACALANUS_PARVUS    Paracalanus parvus
# 3102   20121001UNDm2_200     PARACALANUS_PARVUS    Paracalanus parvus
# 5659   20130903UNDm2_200     PARACALANUS_PARVUS    Paracalanus parvus
# 6227   20130930UNDm1_200          PSEUDOCALANUS         Pseudocalanus
# 6388   20130930UNDm5_200               BIVALVIA              Bivalvia
# 6515   20131001HPNm1_200          PSEUDOCALANUS         Pseudocalanus
# 6673   20131003DBDm2_200   OITHONA_SPINIROSTRIS  Oithona spinirostris
# 6766   20131003DBDm4_200          PSEUDOCALANUS         Pseudocalanus
#
#                 sex       lifeStage
# 1196  indeterminate        zoeae Z3
# 1198  indeterminate        zoeae Z4
# 1200  indeterminate        zoeae Z1
# 1204  indeterminate     furcilia F1
# 1441  indeterminate     copepodites
# 1595  indeterminate         unknown
# 2364  indeterminate         unknown
# 2693  indeterminate     furcilia F3
# 2712  indeterminate     furcilia F3
# 3100         female           adult
# 3102           male           adult
# 5659  indeterminate  copepodites C4
# 6227  indeterminate     copepodites
# 6388  indeterminate         unknown
# 6515  indeterminate     copepodites
# 6673  indeterminate     copepodites
# 6766         female           adult
